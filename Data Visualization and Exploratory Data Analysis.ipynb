# %% [markdown]
# # Data Visualization and Exploratory Data Analysis ((EDA))

# %% [markdown]
# Here we will deal with Haberman Dataset which is regarding cancer. So some medical terms or knowledge is required when tackling this Dataset.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
haberdata = pd.read_csv('E:\python project/haberdata.csv')

# %% [markdown]
# # · Age:
# — It represents the age of the patients undergone the surgery. It ranges from 30 to 83. (Can be determine by the code: haberdata[‘age’])
# # · Year-
# Year in which the patients had the operation. It ranges from 1958-1969.
# # Nodes:-
# A lymph node, or lymph gland is a kidney-shaped organ of the lymphatic system, and the adaptive immune system.(reference:-https://en.wikipedia.org/wiki/Lymph_node)
# # Status:
# — Denoted by 1 and 2. 1 means the patient survived 5 years or longer and 2 means the patient died within 5 year

# %% [markdown]
# print (haberdata)

# %%
print (haberdata.head())
# Out:
#    age  year  nodes  status
# 0   30    64      1       1
# 1   30    62      3       1
# 2   30    65      0       1
# 3   31    59      2       1
# 4   31    65      4       1

# %%
haberdata['status'].value_counts()
# Out:
# 1    225
# 2     81
# Name: status, dtype: int64

# %% [markdown]
# 225 patients survived 5 years or longer and sadly 81 patients died within 5 years.

# %%
haberdata.plot(kind='scatter', x='age', y='nodes')
plt.title('Scatter of ages vs nodes')
plt.show()

# %% [markdown]
# The above plot does not give a better understanding

# %% [markdown]
# Using SNS to give a clear image

# %%
sns.set_style('whitegrid')
sns.FacetGrid(haberdata, hue='status', height=5) \
.map(plt.scatter, 'age', 'nodes')\
.add_legend()
plt.title('Scatter plot using seasborn of ages vs nodes')
plt.show()

# %% [markdown]
# # Pair plots:-
# Used to see the behavior of all the features present in the dataset

# %%
sns.set_style('whitegrid')
sns.pairplot(haberdata, hue='status', height=3)
plt.show()

# %% [markdown]
# From the above plot we can get some interesting facts. We can say that plot 6(Year vs Nodes)is readable compared to the other two but certainly we cannot make any concrete observations based on this graph. The plot 4, plot 7 and plot 8 are the inverted plots of plot 2, plot 3 and plot 6 respectively.

# %% [markdown]
# # Box-Plots

# %%
sns.boxplot(x='status',y='nodes', data=haberdata)
plt.legend
plt.title('Box plot')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Histogram:

# %%
sns.FacetGrid(haberdata, hue='status', height=8)\
.map(sns.distplot, 'age')\
.add_legend()
plt.title('Histogram of age')
# Out:
# Text(0.5, 1.0, 'Histogram of age')

# %% [markdown]
# # Violin plots

# %%
sns.violinplot(x='status',y='nodes',data=haberdata)
plt.legend
plt.title('Violin plot')
plt.show()
